# %%
from datasets import load_dataset

# ImageNetV2
img_data = load_dataset("vaishaal/ImageNetV2", cache_dir="/data/ghdrnjs/project")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/envs/dacon/lib/python3.12/site-packages/datasets/builder.py:1767, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1758     writer = writer_class(
#    1759         features=writer._features,
#    1760         path=fpath.replace("SSSSS", f"{shard_id:05d}").replace("JJJJJ", f"{job_id:05d}"),
#    (...)
#    1765         embed_local_files=embed_local_files,
#    1766     )
# -> 1767 example = self.info.features.encode_example(record) if self.info.features is not None else record
#    1768 writer.write(example, key)
#
# File ~/anaconda3/envs/dacon/lib/python3.12/site-packages/datasets/features/features.py:1987, in Features.encode_example(self, example)
# ...

# %%
from datasets import load_dataset

# %%
# ImageNet-Sketch
img_data_sketch = load_dataset("songweig/imagenet_sketch", cache_dir="/data/ghdrnjs/project/imagenetsketch")
# Out:
# ...
# Generating train split:   0%|          | 0/50889 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/envs/dacon/lib/python3.12/site-packages/datasets/builder.py:1767, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1758     writer = writer_class(
#    1759         features=writer._features,
#    1760         path=fpath.replace("SSSSS", f"{shard_id:05d}").replace("JJJJJ", f"{job_id:05d}"),
#    (...)
#    1765         embed_local_files=embed_local_files,
#    1766     )
# -> 1767 example = self.info.features.encode_example(record) if self.info.features is not None else record
#    1768 writer.write(example, key)
#
# ...

# %%
# ImageNet-A
img_data_A = load_dataset()
